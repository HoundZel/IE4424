# %%
# 1. import library
import numpy as np
import matplotlib.pyplot as plt

# %%
# 2. creat data
x = np.linspace(0, 10, 100)  # generate 100 points from 0 to 10
y = np.sin(x)  # calculate sin(x) for all the points

# %%
# 3. draw figure
plt.figure(figsize=(10, 5))
plt.plot(x, y, label='y = sin(x)', color='blue')
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()  # display

# %%
# 4. basic calculation
a = 10
b = 5
sum_ab = a + b  
product_ab = a * b

# %%
print("Sum:", sum_ab)
print("Product:", product_ab)
# Out:
# Sum: 15
# Product: 50

# %%
# 5. define a function
def greet(name):
    return f"Hello, {name}!"

# %%
# Call the function
print(greet("World"))
# Out:
# Hello, World!

# %%
# Data Processing and visualization

import pandas as pd

data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'age': [24, 30, 22, 35],
    'city': ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen']
}

df = pd.DataFrame(data)

print("Content：")
print(df)
# Out:
# Content：
#       name  age       city
# 0    Alice   24    Beijing
# 1      Bob   30   Shanghai
# 2  Charlie   22  Guangzhou
# 3    David   35   Shenzhen

# %%
# draw a bar chart
df.plot(kind='bar', x='name', y='age', color='orange')
plt.title('Data')
plt.ylabel('Age')
plt.show()

# %%
# create array
array1 = np.array([1, 2, 3, 4, 5])
array2 = np.array([6, 7, 8, 9, 10])

# %%
print("array 1:", array1)
print("array 2:", array2)
# Out:
# array 1: [1 2 3 4 5]
# array 2: [ 6  7  8  9 10]

# %%
sum_array = array1 + array2
print("sum result:", sum_array)
# Out:
# sum result: [ 7  9 11 13 15]

# %%
product_array = array1 * array2
print("product result:", product_array)
# Out:
# product result: [ 6 14 24 36 50]

# %%
squared_array = array1 ** 2
print("squared result:", squared_array)
# Out:
# squared result: [ 1  4  9 16 25]

# %%
mean_value = np.mean(array1)
sum_value = np.sum(array1)
max_value = np.max(array1)
min_value = np.min(array1)

print("mean value of array 1:", mean_value)
print("sum value of array 1:", sum_value)
print("max value of array 1:", max_value)
print("min value of array 1:", min_value)
# Out:
# mean value of array 1: 3.0
# sum value of array 1: 15
# max value of array 1: 5
# min value of array 1: 1

# %%
greater_than_three = array1[array1 > 3]
print("Elements of array 1 that are greater than 3:", greater_than_three)
# Out:
# Elements of array 1 that are greater than 3: [4 5]
